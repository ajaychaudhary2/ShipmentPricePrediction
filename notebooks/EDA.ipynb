# %%
import pandas as pd

# %%
data = pd.read_csv(r"E:\Data_Science _master\ML\Shipment_price_prediction\notebooks\data\SCMS_Delivery_History_Dataset.csv")

# %%
data.head()
# Out:
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              EXW           Air  ...
# 1   PMO - US  Direct Drop              EXW           Air  ...
# 2   PMO - US  Direct Drop              FCA           Air  ...
# 3   PMO - US  Direct Drop              EXW           Air  ...
# 4   PMO - US  Direct Drop              EXW           Air  ...
#
#   Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 0                         30                 19           551.0      29.00
# ...

# %%
data.tail()
# Out:
#           ID Project Code       PQ # PO / SO # ASN/DN #        Country  \
# 10319  86818   103-ZW-T30  FPQ-15197  SO-50020  DN-4307       Zimbabwe
# 10320  86819   104-CI-T30  FPQ-15259  SO-50102  DN-4313  Côte d'Ivoire
# 10321  86821   110-ZM-T30  FPQ-14784  SO-49600  DN-4316         Zambia
# 10322  86822   200-ZW-T30  FPQ-16523  SO-51680  DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30  FPQ-15197  SO-50022  DN-4336       Zimbabwe
#
#       Managed By Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 10319   PMO - US    From RDC   N/A - From RDC         Truck  ...
# 10320   PMO - US    From RDC   N/A - From RDC         Truck  ...
# 10321   PMO - US    From RDC   N/A - From RDC         Truck  ...
# 10322   PMO - US    From RDC   N/A - From RDC         Truck  ...
# 10323   PMO - US    From RDC   N/A - From RDC         Truck  ...
#
#       Unit of Measure (Per Pack) Line Item Quantity Line Item Value  \
# 10319                         60             166571       599655.60
# ...

# %%
data
# Out:
#           ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0          1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1          3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2          4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3         15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4         16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
# ...      ...          ...             ...       ...      ...            ...
# 10319  86818   103-ZW-T30       FPQ-15197  SO-50020  DN-4307       Zimbabwe
# 10320  86819   104-CI-T30       FPQ-15259  SO-50102  DN-4313  Côte d'Ivoire
# 10321  86821   110-ZM-T30       FPQ-14784  SO-49600  DN-4316         Zambia
# 10322  86822   200-ZW-T30       FPQ-16523  SO-51680  DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30       FPQ-15197  SO-50022  DN-4336       Zimbabwe
#
# ...

# %%
imp_col = [
    "Shipment Mode",
    "Weight (Kilograms)",
    "Country",
    "Vendor INCO Term",
    "Line Item Quantity",
    "Freight Cost (USD)",
    "Line Item Insurance (USD)",
    "Line Item Value"
    
    
    
    
]

# %%
data["Line Item Insurance (USD)"].isnull().sum()
# Out:
# 287

# %%
data["Line Item Insurance (USD)"].shape
# Out:
# (10324,)

# %%
data["Line Item Value"].isnull().sum()
# Out:
# 0

# %%
df = data[imp_col]

# %%
df
# Out:
#       Shipment Mode          Weight (Kilograms)        Country  \
# 0               Air                          13  Côte d'Ivoire
# 1               Air                         358        Vietnam
# 2               Air                         171  Côte d'Ivoire
# 3               Air                        1855        Vietnam
# 4               Air                        7590        Vietnam
# ...             ...                         ...            ...
# 10319         Truck     See DN-4307 (ID#:83920)       Zimbabwe
# 10320         Truck     See DN-4313 (ID#:83921)  Côte d'Ivoire
# 10321         Truck  Weight Captured Separately         Zambia
# 10322         Truck                        1392       Zimbabwe
# 10323         Truck  Weight Captured Separately       Zimbabwe
#
#       Vendor INCO Term  Line Item Quantity  \
# 0                  EXW                  19
# 1                  EXW                1000
# 2                  FCA                 500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Shipment Mode              9964 non-null   object
#  1   Weight (Kilograms)         10324 non-null  object
#  2   Country                    10324 non-null  object
#  3   Vendor INCO Term           10324 non-null  object
#  4   Line Item Quantity         10324 non-null  int64
#  5   Freight Cost (USD)         10324 non-null  object
#  6   Line Item Insurance (USD)  10037 non-null  float64
#  7   Line Item Value            10324 non-null  float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 645.4+ KB

# %%
df.isnull().sum()
# Out:
# Shipment Mode                360
# Weight (Kilograms)             0
# Country                        0
# Vendor INCO Term               0
# Line Item Quantity             0
# Freight Cost (USD)             0
# Line Item Insurance (USD)    287
# Line Item Value                0
# dtype: int64

# %%
df['Shipment Mode'].fillna(df['Shipment Mode'].mode()[0], inplace=True)
# Out:
# C:\Users\91740\AppData\Local\Temp\ipykernel_16392\440343416.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Shipment Mode'].fillna(df['Shipment Mode'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Shipment Mode                  0
# Weight (Kilograms)             0
# Country                        0
# Vendor INCO Term               0
# Line Item Quantity             0
# Freight Cost (USD)             0
# Line Item Insurance (USD)    287
# Line Item Value                0
# dtype: int64

# %%
df['Shipment Mode'].fillna(df['Shipment Mode'].mode()[0], inplace=True)

# %%
df['Line Item Insurance (USD)'].fillna(df['Line Item Insurance (USD)'].median(), inplace=True)
# Out:
# C:\Users\91740\AppData\Local\Temp\ipykernel_16392\3418564419.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Line Item Insurance (USD)'].fillna(df['Line Item Insurance (USD)'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Shipment Mode                0
# Weight (Kilograms)           0
# Country                      0
# Vendor INCO Term             0
# Line Item Quantity           0
# Freight Cost (USD)           0
# Line Item Insurance (USD)    0
# Line Item Value              0
# dtype: int64

# %%
df.dtypes
# Out:
# Shipment Mode                 object
# Weight (Kilograms)            object
# Country                       object
# Vendor INCO Term              object
# Line Item Quantity             int64
# Freight Cost (USD)            object
# Line Item Insurance (USD)    float64
# Line Item Value              float64
# dtype: object

# %%
print(df['Freight Cost (USD)'].unique())
# Out:
# ['780.34' '4521.5' '1653.78' ... '26180' '3410' 'See DN-4282 (ID#:83919)']

# %%
df['Freight Cost (USD)'] = pd.to_numeric(df['Freight Cost (USD)'], errors='coerce')
# Out:
# C:\Users\91740\AppData\Local\Temp\ipykernel_16392\2159013057.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Freight Cost (USD)'] = pd.to_numeric(df['Freight Cost (USD)'], errors='coerce')

# %%
df.dtypes
# Out:
# Shipment Mode                 object
# Weight (Kilograms)            object
# Country                       object
# Vendor INCO Term              object
# Line Item Quantity             int64
# Freight Cost (USD)           float64
# Line Item Insurance (USD)    float64
# Line Item Value              float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Shipment Mode                   0
# Weight (Kilograms)              0
# Country                         0
# Vendor INCO Term                0
# Line Item Quantity              0
# Freight Cost (USD)           4126
# Line Item Insurance (USD)       0
# Line Item Value                 0
# dtype: int64

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
df[['Freight Cost (USD)']] = imputer.fit_transform(df[['Freight Cost (USD)']])
# Out:
# C:\Users\91740\AppData\Local\Temp\ipykernel_16392\1116690547.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Freight Cost (USD)']] = imputer.fit_transform(df[['Freight Cost (USD)']])

# %%
df.isnull().sum()
# Out:
# Shipment Mode                0
# Weight (Kilograms)           0
# Country                      0
# Vendor INCO Term             0
# Line Item Quantity           0
# Freight Cost (USD)           0
# Line Item Insurance (USD)    0
# Line Item Value              0
# dtype: int64

# %%
df["Freight Cost (USD)"].head()
# Out:
# 0      780.34
# 1     4521.50
# 2     1653.78
# 3    16007.06
# 4    45450.08
# Name: Freight Cost (USD), dtype: float64

# %%
df["Freight Cost (USD)"].tail()
# Out:
# 10319    11103.234819
# 10320    11103.234819
# 10321    11103.234819
# 10322    11103.234819
# 10323    11103.234819
# Name: Freight Cost (USD), dtype: float64

# %%
df["Freight Cost (USD)"].sample(30)
# Out:
# 8431     9348.000000
# 1063     6667.000000
# 4165    21087.700000
# 698      1629.000000
# 9061     3580.360000
# 4026    37744.270000
# 5243      766.620000
# 9155    11103.234819
# 7158    13398.060000
# 4939    22223.950000
# 7262    11103.234819
# 7288     3026.620000
# 2246     1012.180000
# 7540    11103.234819
# 3184     9195.610000
# 2447    11103.234819
# 8345    11103.234819
# 6104    20618.550000
# 3419    14890.630000
# 4667      820.560000
# 1213    11103.234819
# 8334       22.290000
# 364     11103.234819
# 2879      334.650000
# 2829     9275.590000
# 9478      226.250000
# 1898    11103.234819
# 8663    11320.560000
# 6322     2865.220000
# 8373    11103.234819
# Name: Freight Cost (USD), dtype: float64

# %%
df.tail()
# Out:
#       Shipment Mode          Weight (Kilograms)        Country  \
# 10319         Truck     See DN-4307 (ID#:83920)       Zimbabwe
# 10320         Truck     See DN-4313 (ID#:83921)  Côte d'Ivoire
# 10321         Truck  Weight Captured Separately         Zambia
# 10322         Truck                        1392       Zimbabwe
# 10323         Truck  Weight Captured Separately       Zimbabwe
#
#       Vendor INCO Term  Line Item Quantity  Freight Cost (USD)  \
# 10319   N/A - From RDC              166571        11103.234819
# 10320   N/A - From RDC               21072        11103.234819
# 10321   N/A - From RDC              514526        11103.234819
# 10322   N/A - From RDC               17465        11103.234819
# 10323   N/A - From RDC               36639        11103.234819
#
#        Line Item Insurance (USD)  Line Item Value
# 10319                     705.79        599655.60
# 10320                     161.71        137389.44
# 10321                    5284.04       5140114.74
# ...

# %%
df["Vendor INCO Term"].unique()
# Out:
# array(['EXW', 'FCA', 'DDU', 'CIP', 'DDP', 'CIF', 'N/A - From RDC', 'DAP'],
#       dtype=object)

# %%
df["Shipment Mode"].unique()
# Out:
# array(['Air', 'Truck', 'Air Charter', 'Ocean'], dtype=object)

# %%
df["Country"].unique()
# Out:
# array(["Côte d'Ivoire", 'Vietnam', 'Nigeria', 'Zambia', 'Tanzania',
#        'Rwanda', 'Haiti', 'Zimbabwe', 'Ethiopia', 'South Africa',
#        'Guyana', 'Namibia', 'Botswana', 'Mozambique', 'Kenya',
#        'Kazakhstan', 'Uganda', 'Kyrgyzstan', 'Senegal', 'Benin',
#        'Lesotho', 'Pakistan', 'Swaziland', 'Ghana', 'Angola', 'Lebanon',
#        'Sierra Leone', 'Cameroon', 'South Sudan', 'Burundi',
#        'Dominican Republic', 'Malawi', 'Congo, DRC', 'Sudan', 'Mali',
#        'Guatemala', 'Togo', 'Afghanistan', 'Liberia', 'Burkina Faso',
#        'Guinea', 'Libya', 'Belize'], dtype=object)

# %%
datatypes =df.dtypes

print(datatypes)
# Out:
# Shipment Mode                 object
# Weight (Kilograms)            object
# Country                       object
# Vendor INCO Term              object
# Line Item Quantity             int64
# Freight Cost (USD)           float64
# Line Item Insurance (USD)    float64
# Line Item Value              float64
# dtype: object

# %%
# Step 1: Print unique values in Weight (Kilograms)
print("Unique values in Weight (Kilograms):", df['Weight (Kilograms)'].unique())

# Step 2: Replace non-numeric values with NaN
df['Weight (Kilograms)'] = pd.to_numeric(df['Weight (Kilograms)'], errors='coerce')

# Step 3: Check how many NaN values were created
print("Number of missing values in Weight (Kilograms):", df['Weight (Kilograms)'].isnull().sum())

# Step 4: Decide how to handle NaN values
# For example, filling with the median
df['Weight (Kilograms)'].fillna(df['Weight (Kilograms)'].median(), inplace=True)

# Optional: Convert to integer if required
df['Weight (Kilograms)'] = df['Weight (Kilograms)'].astype(int)

# Check the final DataFrame
# Out:
# Unique values in Weight (Kilograms): [   13   358   171 ... 15198  1547  1392]
# Number of missing values in Weight (Kilograms): 0
# C:\Users\91740\AppData\Local\Temp\ipykernel_16392\3706093684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight (Kilograms)'] = pd.to_numeric(df['Weight (Kilograms)'], errors='coerce')
# C:\Users\91740\AppData\Local\Temp\ipykernel_16392\3706093684.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight (Kilograms)'].fillna(df['Weight (Kilograms)'].median(), inplace=True)
# ...

# %%
df.isnull().sum()
# Out:
# Shipment Mode                0
# Weight (Kilograms)           0
# Country                      0
# Vendor INCO Term             0
# Line Item Quantity           0
# Freight Cost (USD)           0
# Line Item Insurance (USD)    0
# Line Item Value              0
# dtype: int64

# %%
df.dtypes
# Out:
# Shipment Mode                 object
# Weight (Kilograms)             int32
# Country                       object
# Vendor INCO Term              object
# Line Item Quantity             int64
# Freight Cost (USD)           float64
# Line Item Insurance (USD)    float64
# Line Item Value              float64
# dtype: object

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

# %%
numeric_cols
# Out:
# Index(['Line Item Quantity', 'Freight Cost (USD)', 'Line Item Insurance (USD)',
#        'Line Item Value'],
#       dtype='object')

# %%
categorical_cols
# Out:
# Index(['Shipment Mode', 'Country', 'Vendor INCO Term'], dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 6))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(2, len(numeric_cols) // 2 + 1, i)
    sns.histplot(df[col], bins=10, kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
for i, col in enumerate(categorical_cols, 1):
    plt.subplot(2, len(categorical_cols) // 2 + 1, i)
    sns.countplot(data=df, x=col)
    plt.title(f'Count of {col}')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Q1 = df['Freight Cost (USD)'].quantile(0.25)
Q3 = df['Freight Cost (USD)'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Step 2: Remove Outliers
df = df[(df['Freight Cost (USD)'] >= lower_bound) & (df['Freight Cost (USD)'] <= upper_bound)]

# Optional: Visualizing Outliers
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['Freight Cost (USD)'])
plt.title('Box Plot Before Removing Outliers')
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_no_outliers['Freight Cost (USD)'])
plt.title('Box Plot After Removing Outliers')
plt.show()
# Out:
#       Shipment Mode  Weight (Kilograms)        Country Vendor INCO Term  \
# 0               Air                  13  Côte d'Ivoire              EXW
# 1               Air                 358        Vietnam              EXW
# 2               Air                 171  Côte d'Ivoire              FCA
# 3               Air                1855        Vietnam              EXW
# 5               Air                 504        Nigeria              EXW
# ...             ...                 ...            ...              ...
# 10319         Truck                1047       Zimbabwe   N/A - From RDC
# 10320         Truck                1047  Côte d'Ivoire   N/A - From RDC
# 10321         Truck                1047         Zambia   N/A - From RDC
# 10322         Truck                1392       Zimbabwe   N/A - From RDC
# 10323         Truck                1047       Zimbabwe   N/A - From RDC
#
#        Line Item Quantity  Freight Cost (USD)  Line Item Insurance (USD)  \
# ...

# %%
df
# Out:
#       Shipment Mode  Weight (Kilograms)        Country Vendor INCO Term  \
# 0               Air                  13  Côte d'Ivoire              EXW
# 1               Air                 358        Vietnam              EXW
# 2               Air                 171  Côte d'Ivoire              FCA
# 3               Air                1855        Vietnam              EXW
# 5               Air                 504        Nigeria              EXW
# ...             ...                 ...            ...              ...
# 10319         Truck                1047       Zimbabwe   N/A - From RDC
# 10320         Truck                1047  Côte d'Ivoire   N/A - From RDC
# 10321         Truck                1047         Zambia   N/A - From RDC
# 10322         Truck                1392       Zimbabwe   N/A - From RDC
# 10323         Truck                1047       Zimbabwe   N/A - From RDC
#
#        Line Item Quantity  Freight Cost (USD)  Line Item Insurance (USD)  \
# ...

# %%
plt.figure(figsize=(12, 6))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(2, len(numeric_cols) // 2 + 1, i)
    sns.histplot(df[col], bins=10, kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
for col in numeric_cols:
    
    
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

# Step 2: Remove Outliers
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

# Optional: Visualizing Outliers
    plt.figure(figsize=(10, 5))
    sns.boxplot(x=df[col])
    plt.title('Box Plot Before Removing Outliers')
    plt.show()

    plt.figure(figsize=(10, 5))
    sns.boxplot(x=df[col])
    plt.title('Box Plot After Removing Outliers')
    plt.show()

# %%
plt.figure(figsize=(12, 6))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(2, len(numeric_cols) // 2 + 1, i)
    sns.histplot(df[col], bins=10, kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
df[numeric_cols].shape
# Out:
# (6621, 4)

# %%
df[categorical_cols].shape
# Out:
# (6621, 3)

# %%
df["Freight Cost (USD)"].shape
# Out:
# (6621,)

# %%
# Step 1: Identify and Remove Outliers
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

for col in numeric_cols:
    # Visualize Before Removing Outliers
    plt.figure(figsize=(10, 5))
    sns.boxplot(x=df[col])
    plt.title(f'Box Plot Before Removing Outliers for {col}')
    plt.show()
    
    # Calculate IQR
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    # Define bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Step 2: Remove Outliers
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    
    # Visualize After Removing Outliers
    plt.figure(figsize=(10, 5))
    sns.boxplot(x=df[col])
    plt.title(f'Box Plot After Removing Outliers for {col}')
    plt.show()

# %%
plt.figure(figsize=(12, 6))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(2, len(numeric_cols) // 2 + 1, i)
    sns.histplot(df[col], bins=10, kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()
